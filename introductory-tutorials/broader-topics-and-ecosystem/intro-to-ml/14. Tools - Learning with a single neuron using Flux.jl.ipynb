# %% [markdown]
# # Learning with a single neuron using Flux.jl
#
# In this notebook, we'll use `Flux` to create a single neuron and teach it to learn, as we did by hand in notebook 10!

# %% [markdown]
# ### Read in data and process it
#
# Let's start by reading in our data

# %%
using CSV
using TextParse
using DataFrames

applecols, applecolnames = TextParse.csvread("data/Apple_Golden_1.dat", '\t')
bananacols, bananacolnames = TextParse.csvread("data/bananas.dat", '\t')

apples = DataFrame(Dict{String, Any}(strip(name)=>col for (name, col) in zip(applecolnames, applecols)))
bananas = DataFrame(Dict{String, Any}(strip(name)=>col for (name, col) in zip(bananacolnames, bananacols)));

# %% [markdown]
# and processing it to extract information about the red and green coloring in our images:

# %%
col1 = :red
col2 = :green

x_apples  = [ [apples[i, col1], apples[i, col2]] for i in 1:size(apples)[1] ]
x_bananas = [ [bananas[i, col1], bananas[i, col2]] for i in 1:size(bananas)[1] ]

xs = vcat(x_apples, x_bananas)

ys = vcat( zeros(size(x_apples)[1]), ones(size(x_bananas)[1]) );

# %% [markdown]
# The input data is in `xs` and the labels (true classifications as bananas or apples) in `ys`.

# %% [markdown]
# ### Using `Flux.jl`

# %% [markdown]
# Now we can load `Flux` to really get going!

# %%
using Flux
# Out:
# loaded

# %% [markdown]
# We saw in the last notebook that σ is a built-in function in `Flux`.
#
# Another function that is used a lot in neural networks is called `ReLU`; in Julia, the function is called `relu`.

# %% [markdown]
# #### Exercise 1
#
# Use the docs to discover what `ReLU` is all about.
#
# `relu.([-3, 3])` returns
#
# A) [-3, 3] <br>
# B) [0, 3] <br>
# C) [0, 0] <br>
# D) [3, 3] <br>

# %%
relu.([-3, 3])
# Out:
# 2-element Array{Int64,1}:
#  0
#  3

# %% [markdown]
# ### Making a single neuron in Flux

# %% [markdown]
# Let's use `Flux` to build our neuron with 2 inputs and 1 output:
#
#  <img src="data/single-neuron.png" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# We previously put the two weights in a vector, $\mathbf{w}$. Flux instead puts weights in a $1 \times 2$ matrix (i.e. a matrix with 1 *row* and 2 *columns*).
#
# Previously, to compute the dot product of $\mathbf{w}$ and $\mathbf{x}$ we had to use either the `dot` function, or we had to transpose the vector $\mathbf{w}$:
#
# ```julia
# # transpose w
# b = w' * x
# # or use dot!
# b = dot(w, x)
# ```
# If the weights are instead stored in a $1 \times 2$ matrix, `W`, then we can simply multiply `W` and `x` together instead!
#
# We start off with random values for our parameters and data:

# %%
W = rand(1, 2)
# Out:
# 1×2 Array{Float64,2}:
#  0.0316797  0.0684795

# %%
x = rand(2)
# Out:
# 2-element Array{Float64,1}:
#  0.8097524904743549
#  0.5948179502909527

# %% [markdown]
# Note that the product of `W` and `x` will now be an array (vector) with a single element, rather than a single number:

# %%
W * x
# Out:
# 1-element Array{Float64,1}:
#  0.06638552888249623

# %% [markdown]
# This means that our bias `b` is treated as an array when we're using `Flux`:

# %%
b = rand(1)
# Out:
# 1-element Array{Float64,1}:
#  0.026156977654309355

# %% [markdown]
# #### Exercise 2
#
# Write a function `mypredict` that will take a single input, array `x` and use `W`, `b`, and built-in `σ` to generate an output prediction (stored as an array). This function defines our neural network!
#
# Hint: This function will look very similar to $f_{\mathbf{w},\mathbf{b}}$ from the last notebook but has changed since our data structures to store our parameters have changed!

# %%
function mypredict(x)
    return σ.(W*x .+ b)
end
# Out:
# mypredict (generic function with 1 method)

# %% [markdown]
# #### Exercise 3
#
# Define a loss function called `loss`.
#
# `loss` should take two inputs: a vector storing data, `x`, and a vector storing the correct "labels" for that data. `loss` should return the sum of the squares of differences between the predictions and the correct labels.

# %%
function loss(x, labels)
    return sum((labels .- mypredict(x)) .^ 2.0)
end
# Out:
# loss (generic function with 1 method)

# %% [markdown]
# ## Calculating gradients using Flux: backpropagation

# %% [markdown]
# For learning, we know that what we need is a way to calculate derivatives of the `loss` function with respect to the parameters `W` and `b`. So far, we have been doing that using finite differences.
#
# `Flux.jl` instead implements a numerical method called **backpropagation** that calculates gradients (essentially) exactly, in an automatic way, by indirectly applying the rules of calculus.
# To do so, it provides a new type of object called "tracked" arrays. These are arrays that store not only their current value, but also information about gradients, which is used by the backpropagation method.
#
# [If you want to understand the maths behind backpropagation, we recommend e.g. [this lecture](https://www.youtube.com/watch?v=i94OvYb6noo).]

# %% [markdown]
# To do so, `Flux` provides a function `param` to define such objects that will contain the information for a *param*eter.

# %% [markdown]
# Let's start, as usual, by setting up some random initial values for the parameters:

# %%
W_data = rand(1, 2)  
b_data = rand(1)

W_data, b_data
# Out:
# ([0.293795 0.492515], [0.247829])

# %% [markdown]
# We now set up `Flux.jl` objects that will contain these values *and* their derivatives, and allow to propagate
# this information around:

# %%
W = param(W_data)
b = param(b_data)
# Out:
# Tracked 1-element Array{Float64,1}:
#  0.24782853276082428

# %% [markdown]
# Here, `param` is a function that `Flux` provides to create an object that represents a parameter of a machine learning model, i.e. an object which has both a value and derivative information, and such that other objects know how to *keep track* of when it is used in an expression.

# %% [markdown]
# #### Exercise 4
#
# What type does `W` have?
#
# A) Array (1D) <br>
# B) Array (2D) <br>
# C) TrackedArray (1D) <br>
# D) TrackedArray (2D) <br>
# E) Parameter (1D) <br>
# F) Parameter (2D) <br>

# %%
W
# Out:
# Tracked 1×2 Array{Float64,2}:
#  0.293795  0.492515

# %% [markdown]
# #### Exercise 5
#
# `W` stores not only its current value, but also has space to store gradient information. You can access the values and gradient of the weights as follows:
#
# ```julia
# W.data
# W.grad
# ```
#
# At this point, are the values of the weights or the gradient of the weights larger?
#
# A) the values of the weights <br>
# B) the gradient of the weights

# %%
println(W.data)
println(W.grad)
# Out:
# [0.293795 0.492515]
# [0.0 0.0]

# %% [markdown]
# #### Exercise 6
#
# For data `x` and `y` where
#
# ```julia
# x, y = [0.413759, 0.692204], [0.845677]
# ```
# apply the loss function to `x` and `y` to give a new variable `l`. What is the type of `l`? (How many dimensions does it have?)
#
# A) Array (0D) <br>
# <font color="red">B) Array (1D) </font><br>
# C) TrackedArray (0D) <br>
# D) TrackedArray (1D)<br>
# E) Float64<br>
# F) Int64<br>

# %%
x, y = [0.413759, 0.692204], [0.845677]
y
# Out:
# 1-element Array{Float64,1}:
#  0.845677

# %%
loss(xs[1], ys[1])
# Out:
# 0.46775778139994906 (tracked)

# %% [markdown]
# ### Stochastic gradient descent

# %% [markdown]
# We can now use these features to reimplement stochastic gradient descent, following the method we used in the previous notebook, but now using backpropagation!

# %% [markdown]
# #### Exercise 7
#
# Modify the code from the previous notebook for stochastic gradient descent to use Flux instead.

# %%
# \nabla
# Out:
# syntax: "\" is not a unary operator

# %%
function stochastic_gradient_descent(L::Function, w, b, xs, ys, N = 1000)
    
    for iter in 1:N
        rand_index = rand(1:size(xs)[1])
        
        println(w, b, L(xs[rand_index], ys[rand_index]), 
            sum(L(x, y) for (x, y) in (xs, ys)))
    end
    return w, b
end
# Out:
# stochastic_gradient_descent (generic function with 2 methods)

# %% [markdown]
# ### Investigating stochastic gradient descent

# %% [markdown]
# Let's look at the values stored in `b` before we run stochastic gradient descent:

# %%
b
# Out:
# Tracked 1-element Array{Float64,1}:
#  0.24782853276082428

# %% [markdown]
# After running `stochastic_gradient_descent`, we find the following:

# %%
W_final, b_final = stochastic_gradient_descent(loss, W, b, xs, ys, 100000)
# Out:
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2058757301440381 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3114901394747774 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30850217012771475 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2053468210001131 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30747474757281207 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3114173262986272 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3114063909930588 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30581655725215684 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21215108522270928 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30791990476187786 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3117088101256914 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20290897650775386 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20294568647283973 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20294568647283973 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30796342183198205 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2034909483991268 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2055519482278056 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20251732883765214 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20489965139608196 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20837088870361986 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3058834540401764 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2046275466809334 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3125069057386896 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2034820211692723 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2091948128942318 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2107791175191497 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2039809859463719 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20384303075915497 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2030067832398888 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30796910676411926 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21385250667546568 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2037033554338239 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21307886523787828 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3087009413360576 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2034026317832009 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30792694383530206 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3053967491600473 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30803587069421917 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30554209126547643 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20319911176525435 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20935014718117115 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30817989785928623 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20426897686642118 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30518611295134856 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3087554879865718 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2062566418766334 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3111080208317389 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3048323097004766 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21307886523787828 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2088945026380141 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3116757350196938 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20372309035637357 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20393930616381528 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3062120758826251 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31109508289278526 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3117154071246166 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2059247889649341 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20803909365983278 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3115512210065849 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2053468210001131 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20885464976599524 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20750264735692364 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30580475911121235 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30692295873443765 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31103616387952393 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21022032971858512 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2037449736976755 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3062120758826251 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2106235440241226 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20530969921307618 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20342954985220188 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3057607675784368 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2065871139372226 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3052413035333677 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30545117994306276 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3107404265075864 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3122107480064756 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20444749459978964 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31184424779120684 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30692911599223605 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3114901394747774 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20652385493004966 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2056590906823561 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30603515232004863 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2062566418766334 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20970743633286432 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30525194534972017 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2034916919484368 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2035910705004009 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2098499751786289 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20536822895604917 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3084621670240744 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3117457819951879 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2049255361004519 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20290897650775386 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3098976049089613 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3115185384697161 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20501289557844957 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20676253086188096 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31023328247871773 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2133403677233071 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30525194534972017 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30815715133354565 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31069612871192226 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3057496959707838 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20924932414202846 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21123089618072924 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3072416338714149 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2037893307146059 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20322544191594846 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20899236839352517 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3121310677808834 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31138300143931974 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20489965139608196 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21322273405908576 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3080373979000284 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20637923650805773 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21056913078455475 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30888011239223995 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3069209404746166 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20560354234251801 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.307940509635017 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.311651295504863 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30730472042891077 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20698844948090891 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20358417370166643 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20723403474447633 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20308989349762874 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21385250667546568 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20217253673150373 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30538531764065524 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31152638648291137 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20521699882035435 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2044360317774292 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3111909069818756 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.307940509635017 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2041346018016991 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21289031863516614 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2077166089046645 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3081090428237254 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3113116733139069 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20486193199160532 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2039809859463719 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21113229421989743 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31255551342659493 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3116588512004886 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20501289557844957 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3065493649638104 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31172578553238706 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2084792056471295 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31021754864764106 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3075192854385317 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20254030420481856 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30559731332252726 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30555958422187324 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20324685782230784 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2107791175191497 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.306118675656714 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3096415220042166 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20237655909565946 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3116140083479278 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3079244586127301 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3115393213542117 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3062145750834975 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31258615854474686 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20942273716149992 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3115727916648304 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20868043013882082 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20258341355993856 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3072416338714149 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20935014718117115 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3088939847160924 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20812372545232688 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20909954641767578 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20647346065379218 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20883371375070578 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30808332952762485 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20421057615147778 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30605404314358575 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3117594159271095 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20509664871345779 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21006007922500625 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3078319056335528 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3122166783057523 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30494776571099924 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30570122806687605 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21139122118870055 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3115470260341066 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3080373979000284 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3116872761457746 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31023328247871773 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30818471678203124 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3125828442412614 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20836044265213013 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2093263459342296 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3114538415832019 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31249476505588536 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31248921456560785 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30757187922983115 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21036368830772958 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3112460711592221 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2071737487401659 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2057901246234774 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20414405242031922 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20912260116972134 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2092240373239731 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2112090896453651 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3054419369436251 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30642422024291655 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20912260116972134 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2035910705004009 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2088080412083253 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31231982528507646 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31252032497581067 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31152638648291137 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20288571297300195 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21017949863207214 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31254391242404905 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3116122201159649 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3063818431021466 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30546347268062857 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30559731332252726 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3113159405350328 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3096415220042166 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21044215108416686 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3113910303826471 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21376773202982147 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2030067832398888 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3098279999287354 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21215108522270928 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30815715133354565 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21053590316401619 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30525194534972017 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31152638648291137 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3115582103890389 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20849780292203504 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20577022692193958 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30559731332252726 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31257246082571927 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20989929426127119 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30553403984555016 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20284025549096515 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.307376621348899 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20607469221184424 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3065225724844011 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30796910676411926 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20845519870896342 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2114366790816614 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20624727776865256 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31207260356854666 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3099743929703241 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31160883977402415 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21248801925921712 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30619558731171853 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20288571297300195 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21260336309287126 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.209934602782121 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2087831943399315 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20925212719451067 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2101916543776594 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.305008608476436 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2035910705004009 (tracked)0.5041559398124698 (tracked)
# ...
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2036399181967213 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3121310677808834 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30555958422187324 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3085285135879928 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30526703346833717 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20335075688138307 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2093263459342296 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30590970356683206 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20544524314502915 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20676253086188096 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20942273716149992 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20925212719451067 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20525273636993904 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31003678330531087 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20539556762420133 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31161251857078687 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.304858322000372 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20358417370166643 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20661597052149333 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30923332417601423 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31242044973210004 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20690721212760269 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3081567557184316 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2104389588211411 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30514781039191485 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3122107480064756 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.305008608476436 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21312962307160557 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30809546395304876 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20546013527041526 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21054020823853176 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20300255779927331 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3069209404746166 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3098279999287354 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3072653244928981 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31169849065164096 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31266731159298095 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20525834646119762 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20636230474321363 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20644045537124045 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2024267336092048 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3079920640278384 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3110383645344717 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21042205746993134 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20871572419946252 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20363408870171598 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3114449984267123 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30486425437994963 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2048259996661768 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20560221526520164 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31213077335959727 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30668333037272555 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20845519870896342 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31264562776047755 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]
# Excessive output truncated after 524289 bytes.
# Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20962228490383694 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20379760754791276 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.307376621348899 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3077970485413646 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30818471678203124 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3080373979000284 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21131044274128952 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30605404314358575 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20290800148217072 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.209934602782121 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20661597052149333 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3125463668962043 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20798920658309542 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20512680558089066 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2113469755386689 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2071737487401659 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.21100295668142574 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3107404265075864 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20521699882035435 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31173744605332343 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3069209404746166 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20599118573845007 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2074696620345393 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3114336729939745 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3114173262986272 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30727576020619973 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.3085212433236244 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.31168405580146 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.30598944632647457 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2053910997603403 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.20288571297300195 (tracked)0.5041559398124698 (tracked)
# Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)]Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)]0.2089279694901488 (tracked)
# (Flux.Tracker.TrackedReal{Float64}[0.293795 (tracked) 0.492515 (tracked)], Flux.Tracker.TrackedReal{Float64}[0.247829 (tracked)])

# %% [markdown]
# ### we can look at the values of `W_final` and `b_final`, which our machine learned to generate our desired classification.

# %%
W_final
# Out:
# UndefVarError: W_final not defined
#
# Stacktrace:
#  [1] top-level scope at In[20]:1

# %%
b_final
# Out:
# UndefVarError: b_final not defined
#
# Stacktrace:
#  [1] top-level scope at In[21]:1

# %% [markdown]
# #### Exercise 8
#
# Plot the data and the learned function.

# %% [markdown]
# #### Exercise 9
#
# Do this plot every so often as the learning process is proceeding in order to have an animation of the process.

# %% [markdown]
# ### Automation with Flux.jl

# %% [markdown]
# We will need to repeat the above process for a lot of different systems.
# Fortunately, `Flux.jl` provides us with tools to automate this!

# %% [markdown]
# Flux allows to create a neuron in a simple way:

# %%
using Flux

# %%
model = Dense(2, 1, σ)
# Out:
# Dense(2, 1, NNlib.σ)

# %% [markdown]
# The `2` and `1` refer to the number of inputs and outputs, and the neuron is defined using the $\sigma$ function.

# %%
typeof(model)
# Out:
# Dense{typeof(σ),TrackedArray{…,Array{Float64,2}},TrackedArray{…,Array{Float64,1}}}

# %% [markdown]
# We have made an object of type `Dense`, defined by `Flux`, with the name `model`. This represents a "dense neural network layer" (see later for more on neural network layers).
# The parameters that will be modified during the learning process live *inside* the `model` object.

# %% [markdown]
# #### Exercise 10
#
# Investigate which variables live inside the `model` object and what type they are. How does that compare to the call to create the `Dense` object that we started with?

# %% [markdown]
# ### Model object as a function

# %% [markdown]
# We can apply the `model` object to data just as if it were a standard function:

# %%
model(rand(2))
# Out:
# Tracked 1-element Array{Float64,1}:
#  0.5543600633550765

# %% [markdown]
# #### Exercise 11
#
# Prove to yourself that you understand what is going on when we call `model`. Create two arrays `W` and `b` with the same elements as `model.W` and `model.b`. Use `W` and `b` to generate the same answer that you get when we call `model([.5, .5])`.

# %% [markdown]
# ### Using Flux

# %% [markdown]
# We now need to provide Flux with three pieces of information:
#
# 1. A loss function
# 2. Some training data
# 3. An optimization method

# %% [markdown]
# ### Loss functions

# %% [markdown]
# Flux has various loss functions built in, for example the mean-squared error (`mse`) that we have been using:

# %%
loss(x, y) = Flux.mse(model(x), y)
# Out:
# loss (generic function with 1 method)

# %% [markdown]
# Another common one is the cross entropy, `Flux.crossentropy`.

# %% [markdown]
# ### Data

# %% [markdown]
# The data can take a couple of different forms.
# One form is a single **iterator**, consisting of pairs $(x, y)$ of data and labels.
# We can achieve this with `zip`.

# %% [markdown]
# #### Exercise 12
#
# Use `zip` to "zip together" `xs` and `ys`. Then use the `collect` function to check what `zip` actually does.

# %% [markdown]
# ### Optimization routine

# %% [markdown]
# Now we need to tell Flux what kind of optimization routine to use. It has several built in; the standard stochastic gradient descent algorithm that we have been using is called `SGD`. We must pass it two things: a list of parameter objects which will be modified by the optimization routine, and a step size:

# %%
opt = SGD([model.W, model.b], 0.01)
# give a list of the parameters that will be modified
# Out:
# #43 (generic function with 1 method)

# %% [markdown]
# The gradient calculations and parameter updates will be carried out by this optimizer function; we do not see those details, but if you are curious, you can, of course, look at the `Flux.jl` source code!

# %% [markdown]
# ### Training

# %% [markdown]
# We now have all the pieces in place to actually **train** our model (a single neuron) on the data.
# "Training" refers to using pre-labeled data to learn the function that relates the input data to the desired output data given by the labels.
#
# `Flux` provides the function `train!`, which performs a single pass through the data and does a single step of optimization using the partial cost function for each data point:

# %%
Flux.train!(loss, data, opt)
# Out:
# UndefVarError: data not defined
#
# Stacktrace:
#  [1] top-level scope at In[28]:1

# %% [markdown]
# We can then just repeat this several times to train the network more and coax it towards the minimum of the cost function:

# %%
for i in 1:100
    Flux.train!(loss, data, opt)
end
# Out:
# UndefVarError: data not defined
#
# Stacktrace:
#  [1] top-level scope at ./In[29]:2

# %% [markdown]
# Now let's look at the parameters after training:

# %%
model.W
# Out:
# Tracked 1×2 Array{Float64,2}:
#  0.344513  -0.0217488

# %%
model.b
# Out:
# Tracked 1-element Array{Float64,1}:
#  0.0

# %% [markdown]
# Instead of writing out a list of parameters to modify, `Flux` provides the function `params`, which extracts all available parameters from a model:

# %%
opt = SGD(params(model), 0.01)
# Out:
# #43 (generic function with 1 method)

# %%
params(model)
# Out:
# 2-element Array{Any,1}:
#  Flux.Tracker.TrackedReal{Float64}[0.344513 (tracked) -0.0217488 (tracked)]
#  Flux.Tracker.TrackedReal{Float64}[0.0 (tracked)]

# %% [markdown]
# ## Adding more features

# %% [markdown]
# #### Exercise 13
#
# So far we have just used two features, red and green.
#
# (i) Add a third feature, blue. Plot the new data.
#
# (ii) Train a neuron with 3 inputs and 1 output on the data.
#
# (iii) Can you find a good way to visualize the result?
